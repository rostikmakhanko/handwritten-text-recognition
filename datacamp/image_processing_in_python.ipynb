# %% [markdown]
# <a href="https://colab.research.google.com/github/rostikmakhanko/handwritten-text-recognition/blob/master/datacamp/image_processing_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import data
from skimage import color
from matplotlib import pyplot as plt

def show_image(image, title, cmap_type='gray'):
  plt.imshow(image, cmap=cmap_type)
  plt.title(title)
  plt.axis('off')
  plt.show()

rocket = data.rocket()

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2grey(rocket)

# Show the original image
show_image(rocket, 'Original RGB image')

# Show the grayscale image
show_image(gray_scaled_rocket, 'Grayscale image')

type(rocket)
# Out:
# numpy.ndarray

# %%
red = rocket[:, :, 2]
plt.hist(red.ravel(), bins = 256)
plt.title('Blue Histogram')
plt.show()

# %%
import numpy as np

flipped_rocket = np.flipud(rocket)
show_image(flipped_rocket, 'Flipped rocket')
